# %%
import matplotlib.pyplot as plt

# %%
def traerdatos(x):
    listaprincipal = []

    with open(x) as archivo:
        for linea in archivo:
            listaprincipal.append(float(linea))
    return listaprincipal

# %%
cy1 = traerdatos("tiemposejecucioninsert/tiemposc++insert.txt")

print(cy1)
cx1=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000, 40000, 50000]
plt.plot(x1,y1,marker='o', linestyle='-', color = 'b',label='C++')
plt.legend()
plt.ylabel("Tiempo Promedio despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Tiempo Promedio c++")
plt.show()
# Out:
# [4.94e-05, 0.0007468, 0.0016178, 0.0024382, 0.0030474, 0.0044016, 0.0058914, 0.0066444, 0.0077268, 0.0083686, 0.0106602, 0.0288046, 0.0587294, 0.097735, 0.142042]

# %%
cy2 = traerdatos("desviacionestandarinsert/desviacionestarc++insert.txt")

print(cy2)
cx2=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000, 40000, 50000]
plt.plot(x1,y1,marker='o', linestyle='-', color = 'b',label='C++')
plt.legend()
plt.ylabel("Desviacion Estandar despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Desviacion Estandar c++")
plt.show()
# Out:
# [6.69328e-06, 0.000128233, 0.000108755, 0.00028727, 0.000231854, 0.000554039, 0.000381111, 0.00043798, 0.000396954, 0.000373011, 0.00114422, 0.00260037, 0.00203161, 0.00222856, 0.00209292]

# %%
py1 = traerdatos("tiemposejecucioninsert/tiempospythoninsertsort.txt")

print(py1)
px1=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000, 40000, 50000]
plt.plot(x1,y1,marker='o', linestyle='-', color = 'g',label='Python')
plt.legend()
plt.ylabel("Tiempo Promedio despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Tiempo Promedio Python")
plt.show()
# Out:
# [0.00028255999786779283, 0.036831219994928686, 0.14429816000629217, 0.4706908000051044, 0.6474665999994613, 1.3225130000151695, 1.6036105399834923, 2.2862759399693457, 2.996432860009372, 3.552871160011273, 4.497133840015158, 18.780725400010123, 42.5641949800076, 70.83963017999194, 119.5207049199962]

# %%
py2 = traerdatos("desviacionestandarinsert/desviacionstandarpythoninsertsort.txt")

print(py2)
px2=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000, 40000, 50000]
plt.plot(x1,y1,marker='o', linestyle='-', color = 'g',label='Python')
plt.legend()
plt.ylabel("Desviacion Estandar despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Desviacion Estandar Python")
plt.show()
# Out:
# [2.1098528912965407e-05, 0.0042013674931906525, 0.006402389787932977, 0.18466342091070306, 0.04275289444590128, 0.21303727606964337, 0.21643200826547684, 0.41911186429830094, 0.16096707286376888, 0.11987477576352591, 0.26153550140399195, 1.7608278987242538, 2.5084893966631365, 10.384290670626562, 10.00222051857415]

# %%
gy1 = traerdatos("tiemposejecucioninsert/tiemposgo.txt")

print(gy1)
gx1=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000, 40000, 50000]
plt.plot(x1,y1,marker='o', linestyle='-', color = 'r',label='Go')
plt.legend()
plt.ylabel("Tiempo Promedio despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Tiempo Promedio Go")
plt.show()
# Out:
# [0.00019946, 0.00021226, 0.0013035999999999998, 0.0023906400000000003, 0.0033577800000000003, 0.0057347000000000006, 0.007800939999999999, 0.010787020000000001, 0.014411039999999996, 0.01704476, 0.0266339, 0.08932103999999999, 0.21051205999999997, 0.38934966, 0.56804502]

# %%
gy2 = traerdatos("desviacionestandarinsert/desviancionstandargolang.txt")

print(gy2)
gx2=[100,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,
    9000, 10000, 20000, 30000, 40000, 50000]
plt.plot(x1,y1,marker='o', linestyle='-', color = 'r',label='Go')
plt.legend()
plt.ylabel("Desviacion Estandar despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Desviacion Estandar Go")
plt.show()
# Out:
# [0.000446006118792108, 0.00029068365623130586, 0.000629516429491717, 0.0014528918311422913, 0.000599079704213054, 0.0013684817225670205, 0.001015903978238101, 0.00236222073629879, 0.0015154420239652854, 0.0007612111816046841, 0.004063487212973604, 0.0024924073047959084, 0.005170495092638607, 0.0494448426079303, 0.048606012093073414]

# %%
plt.plot(cx1,cy1,marker='o', linestyle='-', color = 'r',label='C++')
plt.plot(gx1,gy1,marker='o', linestyle='-', color = 'b',label='Golang')
plt.plot(px1, py1, marker='o', linestyle='-', color = 'y',label='Python')
plt.legend()
plt.ylabel("Tiempo Promedio despues de 5 iteraciones")
plt.xlabel("Tamaño del array")
plt.title("Comparacion entre tiempos promedios de C++,Golang y python")
plt.show()
